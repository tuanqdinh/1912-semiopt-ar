# %%
# %run train_cifar_ae.py --dataset_name CIFAR10 --model_name AE --num_epochs 10
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch [0/10], Step [0/781], Loss: 0.7634, time: 0.3310s
# Epoch [0/10], Step [10/781], Loss: 0.6644, time: 0.2043s
# Epoch [0/10], Step [20/781], Loss: 0.6112, time: 0.1608s
# Epoch [0/10], Step [30/781], Loss: 0.6116, time: 0.1639s
# Epoch [0/10], Step [40/781], Loss: 0.6088, time: 0.1628s
# Epoch [0/10], Step [50/781], Loss: 0.5905, time: 0.1638s
# Epoch [0/10], Step [60/781], Loss: 0.5895, time: 0.1699s
# Epoch [0/10], Step [70/781], Loss: 0.5997, time: 0.1671s
# Epoch [0/10], Step [80/781], Loss: 0.5944, time: 0.1539s
# Epoch [0/10], Step [90/781], Loss: 0.5852, time: 0.1738s
# Epoch [0/10], Step [100/781], Loss: 0.6029, time: 0.1663s
# Epoch [0/10], Step [110/781], Loss: 0.5872, time: 0.1597s
# Epoch [0/10], Step [120/781], Loss: 0.5780, time: 0.1541s
# Epoch [0/10], Step [130/781], Loss: 0.5957, time: 0.1659s
# Epoch [0/10], Step [140/781], Loss: 0.5791, time: 0.1754s
# ...

# %%
import os
os.environ['KMP_WARNINGS'] = 'off'

# %%
# !python train_cifar_ae_arz.py --num_epochs 1 --log_step 100 --dataset_name CIFAR10 --model_name ARZ
# Out:
# Setting up Perceptual loss...
# Loading model from: /home/aka/Experiments/semioptpixel/src/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done
# Files already downloaded and verified
# Files already downloaded and verified
# Load AE
# Epoch [0/1], Step [0/781], Loss: 32976.3008, time: 1.7956s
# Epoch [0/1], Step [100/781], Loss: 20717.0898, time: 19.4017s
# Epoch [0/1], Step [200/781], Loss: 19585.3242, time: 19.2896s
# Epoch [0/1], Step [300/781], Loss: 19011.3125, time: 19.2862s
# Epoch [0/1], Step [400/781], Loss: 20109.8320, time: 19.2737s
# Epoch [0/1], Step [500/781], Loss: 19061.3477, time: 19.2481s
# Epoch [0/1], Step [600/781], Loss: 19281.1445, time: 19.2489s
# Epoch [0/1], Step [700/781], Loss: 19207.5762, time: 19.3155s
# > /home/aka/Experiments/semioptpixel/src/train_cifar_ae_arz.py(97)<module>()
# -> loss = loss_op(z, out_params).mean()
# (Pdb)
# --KeyboardInterrupt--
# (Pdb)
